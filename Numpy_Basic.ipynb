# %% [markdown]
# <a href="https://colab.research.google.com/github/NITIN9694/TensorFlow-Learning/blob/main/Numpy_Basic.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np

# %% [markdown]
# ##Data Type & Attributes

# %%
a2 = [[1.,2.,3.3],
      [4.,5.,6.5]
      ]

# %%
a2
# Out:
# [[1.0, 2.0, 3.3], [4.0, 5.0, 6.5]]

# %%
import pandas as pd

# %%
df = pd.DataFrame(a2)
df
# Out:
#      0    1    2
# 0  1.0  2.0  3.3
# 1  4.0  5.0  6.5

# %% [markdown]
# ## Creating  Array

# %%
sample_array = np.array([1,2,3])

# %%
sample_array
# Out:
# array([1, 2, 3])

# %%
sample_array.dtype
# Out:
# dtype('int64')

# %%
ones = np.ones((2,3))

# %%
ones
# Out:
# array([[1., 1., 1.],
#        [1., 1., 1.]])

# %%
ones.dtype
# Out:
# dtype('float64')

# %%
range_array = np.arange(0,10,2)

# %%
range_array
# Out:
# array([0, 2, 4, 6, 8])

# %%
random_array = np.random.randint(0,10,size = (3,5))

# %%
random_array
# Out:
# array([[9, 8, 5, 6, 1],
#        [1, 2, 3, 1, 6],
#        [2, 0, 4, 2, 1]])

# %%
random_array.size
# Out:
# 15

# %%
random_array.shape
# Out:
# (3, 5)

# %%
random_array_2= np.random.random((5,3))

# %%
random_array_2.shape
# Out:
# (5, 3)

# %%
 #random_seed
random_array3 = np.random.rand(5,3)

# %%
random_array3
# Out:
# array([[0.66884579, 0.84123267, 0.7650324 ],
#        [0.36459915, 0.83290353, 0.83148474],
#        [0.85774246, 0.2586457 , 0.52468067],
#        [0.15895685, 0.71631299, 0.25174106],
#        [0.47209376, 0.75553148, 0.09186625]])

# %%
np.random.seed(seed=10)
random_array4 = np.random.randint(10,size =( 5,3))
random_array4
# Out:
# array([[9, 4, 0],
#        [1, 9, 0],
#        [1, 8, 9],
#        [0, 8, 6],
#        [4, 3, 0]])

# %% [markdown]
# ##Viewing array and metrics

# %%
a4 = np.random.randint(10,size = (2,3,4,5))
a4
# Out:
# array([[[[4, 6, 8, 1, 8],
#          [4, 1, 3, 6, 5],
#          [3, 9, 6, 9, 1],
#          [9, 4, 2, 6, 7]],
#
#         [[8, 8, 9, 2, 0],
#          [6, 7, 8, 1, 7],
#          [1, 4, 0, 8, 5],
#          [4, 7, 8, 8, 2]],
#
#         [[6, 2, 8, 8, 6],
#          [6, 5, 6, 0, 0],
#          [6, 9, 1, 8, 9],
#          [1, 2, 8, 9, 9]]],
#
#
#        [[[5, 0, 2, 7, 3],
#          [0, 4, 2, 0, 3],
#          [3, 1, 2, 5, 9],
#          [0, 1, 0, 1, 9]],
#
#         [[0, 9, 2, 1, 1],
#          [0, 0, 5, 9, 0],
#          [4, 6, 6, 0, 2],
#          [3, 3, 2, 6, 0]],
#
#         [[5, 1, 3, 6, 5],
#          [5, 1, 8, 0, 5],
#          [9, 8, 5, 7, 8],
#          [5, 8, 9, 9, 1]]]])

# %%
a4.shape
# Out:
# (2, 3, 4, 5)

# %%
a4.ndim
# Out:
# 4

# %%
#Get first 4 number
a4[:,:,:,:1]
# Out:
# array([[[[4],
#          [4],
#          [3],
#          [9]],
#
#         [[8],
#          [6],
#          [1],
#          [4]],
#
#         [[6],
#          [6],
#          [6],
#          [1]]],
#
#
#        [[[5],
#          [0],
#          [3],
#          [0]],
#
#         [[0],
#          [0],
#          [4],
#          [3]],
#
#         [[5],
#          [5],
#          [9],
#          [5]]]])

# %% [markdown]
# ## Manipulating & Comparing arrays

# %%
a1 = np.array([1,2,3])

# %%
a1
# Out:
# array([1, 2, 3])

# %%
one = np.ones(3)
one
# Out:
# array([1., 1., 1.])

# %%
a1 + one
# Out:
# array([2., 3., 4.])

# %%
a2
# Out:
# [[1.0, 2.0, 3.3], [4.0, 5.0, 6.5]]

# %%
a1*a2
# Out:
# array([[ 1. ,  4. ,  9.9],
#        [ 4. , 10. , 19.5]])

# %% [markdown]
# ##Aggregation
# Aggregation = performing the same operation on a number of things

# %%
listy_list = [1,2,3]
type(listy_list)
# Out:
# list

# %%
a1
# Out:
# array([1, 2, 3])

# %%
type(a1)
# Out:
# numpy.ndarray

# %%
sum(a1)
# Out:
# np.int64(6)

# %%
np.sum(a1)
# Out:
# np.int64(6)

# %%
#creative a massive numpy array
massive_array = np.random.random(100000)
massive_array[:10]
# Out:
# array([0.51233415, 0.67346693, 0.15919373, 0.05047767, 0.33781589,
#        0.10806377, 0.17890281, 0.8858271 , 0.36536497, 0.21876935])

# %%
# %timeit sum(massive_array) #pyhton sum
# %timeit np.sum(massive_array) #numpy sum
# Out:
# 12.2 ms ± 3.47 ms per loop (mean ± std. dev. of 7 runs, 100 loops each)
# 35.3 µs ± 1.21 µs per loop (mean ± std. dev. of 7 runs, 10000 loops each)

# %% [markdown]
# Use Python's methods (sum()) on Python datatypes and use Numpy's methods on Numpy arrays (np.sum())

# %%
a2
# Out:
# [[1.0, 2.0, 3.3], [4.0, 5.0, 6.5]]

# %%
np.mean(a2)
# Out:
# np.float64(3.6333333333333333)

# %%
np.max(a2)
# Out:
# np.float64(6.5)

# %%
np.std(a2)
# Out:
# np.float64(1.8226964152656422)

# %%
#variance = measure if the average degree to which each number is diffrent to the mean
# Higer Varince = wider range of numbers
# Lower varince = lower range of numbers
np.var(a2)
# Out:
# np.float64(3.3222222222222224)
